# %% [markdown]
# # **Artigo: Distributional Reinforcement Learning with Quantile Regression**

# %% [markdown]
# ## **Abstract**

# %% [markdown]
# - A ideia principal é tentar modelar a recompensa como uma distribuição e não uma função que retorna apenas a média.
